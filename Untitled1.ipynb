# %%
#匯入必要的library
from __future__ import print_function
from imutils import paths
from scipy.io import loadmat
from skimage import io
import argparse
import dlib
import cv2
import re

# %%
options = dlib.simple_object_detector_training_options()
images = [] #存放相片圖檔
boxes = [] #存放Annotations
 
#依序處理path下的每張圖片

for imagePath in paths.list_images("yilan/forestPark"):
    #從圖片路徑名稱中取出ImageID
    imageID = imagePath[imagePath.rfind("/") + 1:]
    img = cv2.imread(imagePath)
    left, top, height, width = 1, 1, img.shape[0], img.shape[1]
    
    #取出annotations資訊繪成矩形物件，放入boxes變數中。
    bb = [dlib.rectangle(left = left, top = top, right = width, bottom = height)]
    boxes.append(bb)
    
    #將圖片放入images變數
    images.append(io.imread(imagePath))

# %%
boxes
# Out:
# [[rectangle(1,1,259,195)],
#  [rectangle(1,1,276,182)],
#  [rectangle(1,1,259,194)],
#  [rectangle(1,1,275,183)],
#  [rectangle(1,1,259,194)],
#  [rectangle(1,1,275,183)],
#  [rectangle(1,1,156,134)],
#  [rectangle(1,1,225,225)],
#  [rectangle(1,1,276,183)],
#  [rectangle(1,1,225,225)],
#  [rectangle(1,1,259,194)],
#  [rectangle(1,1,225,225)],
#  [rectangle(1,1,225,225)],
#  [rectangle(1,1,259,194)],
#  [rectangle(1,1,135,90)],
#  [rectangle(1,1,300,168)],
#  [rectangle(1,1,259,194)],
#  [rectangle(1,1,275,183)],
#  [rectangle(1,1,197,115)],
#  [rectangle(1,1,225,224)],
#  [rectangle(1,1,259,194)],
#  [rectangle(1,1,150,104)],
#  [rectangle(1,1,225,225)],
#  [rectangle(1,1,225,225)],
#  [rectangle(1,1,225,225)],
#  [rectangle(1,1,310,163)],
#  [rectangle(1,1,275,183)],
#  [rectangle(1,1,276,183)],
#  [rectangle(1,1,225,225)],
#  [rectangle(1,1,247,204)],
#  [rectangle(1,1,169,112)],
#  [rectangle(1,1,275,183)],
#  [rectangle(1,1,267,189)],
#  [rectangle(1,1,150,99)],
#  [rectangle(1,1,225,225)],
#  [rectangle(1,1,321,157)],
#  [rectangle(1,1,300,168)],
#  [rectangle(1,1,275,183)],
#  [rectangle(1,1,265,190)],
#  [rectangle(1,1,275,183)],
#  [rectangle(1,1,209,166)],
#  [rectangle(1,1,259,194)],
#  [rectangle(1,1,300,168)],
#  [rectangle(1,1,275,183)],
#  [rectangle(1,1,251,201)],
#  [rectangle(1,1,275,183)],
#  [rectangle(1,1,225,225)],
#  [rectangle(1,1,259,194)],
#  [rectangle(1,1,299,169)],
#  [rectangle(1,1,225,225)],
#  [rectangle(1,1,258,195)],
#  [rectangle(1,1,275,183)],
#  [rectangle(1,1,225,225)],
#  [rectangle(1,1,225,225)],
#  [rectangle(1,1,275,183)],
#  [rectangle(1,1,275,183)],
#  [rectangle(1,1,148,148)],
#  [rectangle(1,1,225,224)],
#  [rectangle(1,1,251,201)],
#  [rectangle(1,1,275,183)],
#  [rectangle(1,1,275,183)],
#  [rectangle(1,1,275,183)],
#  [rectangle(1,1,225,225)],
#  [rectangle(1,1,275,183)],
#  [rectangle(1,1,259,194)],
#  [rectangle(1,1,225,225)],
#  [rectangle(1,1,225,225)],
#  [rectangle(1,1,225,225)],
#  [rectangle(1,1,275,183)],
#  [rectangle(1,1,275,183)],
#  [rectangle(1,1,271,186)],
#  [rectangle(1,1,256,197)],
#  [rectangle(1,1,143,80)],
#  [rectangle(1,1,143,95)],
#  [rectangle(1,1,284,177)],
#  [rectangle(1,1,148,124)],
#  [rectangle(1,1,275,183)],
#  [rectangle(1,1,151,129)],
#  [rectangle(1,1,225,225)],
#  [rectangle(1,1,276,183)],
#  [rectangle(1,1,275,183)],
#  [rectangle(1,1,276,183)],
#  [rectangle(1,1,225,225)],
#  [rectangle(1,1,225,225)],
#  [rectangle(1,1,225,225)],
#  [rectangle(1,1,150,113)],
#  [rectangle(1,1,199,151)],
#  [rectangle(1,1,225,225)],
#  [rectangle(1,1,67,51)],
#  [rectangle(1,1,251,201)],
#  [rectangle(1,1,260,194)],
#  [rectangle(1,1,225,225)],
#  [rectangle(1,1,225,224)],
#  [rectangle(1,1,259,194)],
#  [rectangle(1,1,225,225)],
#  [rectangle(1,1,275,183)],
#  [rectangle(1,1,143,107)],
#  [rectangle(1,1,271,186)],
#  [rectangle(1,1,259,194)],
#  [rectangle(1,1,259,194)],
#  [rectangle(1,1,275,183)],
#  [rectangle(1,1,275,183)],
#  [rectangle(1,1,181,149)],
#  [rectangle(1,1,225,225)],
#  [rectangle(1,1,206,154)],
#  [rectangle(1,1,275,183)],
#  [rectangle(1,1,259,194)],
#  [rectangle(1,1,275,183)],
#  [rectangle(1,1,143,95)],
#  [rectangle(1,1,225,225)],
#  [rectangle(1,1,240,160)],
#  [rectangle(1,1,139,117)],
#  [rectangle(1,1,284,178)],
#  [rectangle(1,1,225,225)],
#  [rectangle(1,1,247,204)],
#  [rectangle(1,1,275,183)],
#  [rectangle(1,1,225,225)],
#  [rectangle(1,1,225,225)],
#  [rectangle(1,1,234,215)],
#  [rectangle(1,1,275,183)],
#  [rectangle(1,1,135,90)],
#  [rectangle(1,1,259,194)]]
